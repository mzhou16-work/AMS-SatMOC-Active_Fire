# %%
import os
import xarray as xr
from google.colab import drive
from datetime import datetime, timedelta

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
input_dir = "/content/drive/MyDrive/FILDA_DATA_MULTI/"

# %%
filenames = os.listdir(input_dir)

# %%
ds = xr.open_dataset(input_dir + filenames[0])

# %%
ds
# Out:
# <xarray.Dataset> Size: 207MB
# Dimensions:           (nFire: 748, nRow: 6464, nCol: 6400, nRow_QA: 6464,
#                        nCol_QA: 6400)
# Coordinates:
#     FP_Latitude       (nFire) float32 3kB ...
#     FP_Longitude      (nFire) float32 3kB ...
# Dimensions without coordinates: nFire, nRow, nCol, nRow_QA, nCol_QA
# Data variables: (12/77)
#     crs               int32 4B ...
#     DNB_observations  (nFire) float32 3kB ...
#     FP_MCE            (nFire) float32 3kB ...
#     FP_VEF            (nFire) float32 3kB ...
#     FP_Status         (nFire) int8 748B ...
#     FP_Num_Fire       (nFire) int8 748B ...
#     ...                ...
#     FP_Land_Type      (nFire) int8 748B ...
#     FP_Gas_Flaring    (nFire) int8 748B ...
#     FP_Peatland       (nFire) int8 748B ...
#     FP_Peatfrac       (nFire) float32 3kB ...
#     FP_AdjWater       (nFire) int8 748B ...
#     FP_AdjCloud       (nFire) int8 748B ...
# Attributes: (12/44)
#     history:                           Created Sat Nov  9 01:22:38 2024 /tis/...
#     source:                            FILDA detecion on VNP
#     RangeEndingDate:                   2018-11-10
#     DayNightFlag:                      Night
#     PGE_StartTime:                     2018-11-10 09:30:00
#     RangeEndingTime:                   09:36:00.000000
#     ...                                ...
#     AlgorithmType:                     SCI
#     WestBoundingCoordinate:            -134.084
#     AlgorithmVersion:                  NPP_PR47 1.0.0
#     InputPointer:                      VNP02MOD.A2018314.0930.002.20210991910...
#     ProductionTime:                    2024-11-9T6:20:1.000Z
#     RangeBeginningTime:                09:30:00.000000

# %%
ds.close()
